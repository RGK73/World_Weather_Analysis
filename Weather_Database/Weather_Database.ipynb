# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
import time
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
 
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #for weather description
        city_weather_info = city_weather["weather"]
        city_weather_description = city_weather_info[0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          })

#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | dutse
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | san quintin
# Processing Record 6 of Set 1 | nouadhibou
# Processing Record 7 of Set 1 | salaverry
# Processing Record 8 of Set 1 | lebyazhye
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | ahipara
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | leningradskiy
# Processing Record 13 of Set 1 | drakino
# Processing Record 14 of Set 1 | aklavik
# Processing Record 15 of Set 1 | yaan
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | haines junction
# Processing Record 18 of Set 1 | brae
# Processing Record 19 of Set 1 | sibu
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | bandar-e anzali
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | westonaria
# Processing Record 24 of Set 1 | isangel
# Processing Record 25 of Set 1 | hervey bay
# Processing Record 26 of Set 1 | tigil
# Processing Record 27 of Set 1 | sitka
# Processing Record 28 of Set 1 | karratha
# Processing Record 29 of Set 1 | rosita
# Processing Record 30 of Set 1 | koutiala
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 1 | nanortalik
# Processing Record 38 of Set 1 | esperance
# Processing Record 39 of Set 1 | dzilam gonzalez
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | taltal
# Processing Record 42 of Set 1 | talnakh
# Processing Record 43 of Set 1 | chapais
# Processing Record 44 of Set 1 | guicheng
# City not found. Skipping...
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | baoding
# Processing Record 47 of Set 1 | houlton
# Processing Record 48 of Set 1 | nuuk
# Processing Record 49 of Set 1 | shakawe
# Processing Record 50 of Set 1 | kiruna
# Processing Record 1 of Set 2 | shizunai
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | teya
# Processing Record 5 of Set 2 | christchurch
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | barranca
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | klaksvik
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | raga
# Processing Record 14 of Set 2 | fortuna
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 2 | dajal
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | college
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | riyadh
# Processing Record 22 of Set 2 | quzhou
# Processing Record 23 of Set 2 | clyde river
# Processing Record 24 of Set 2 | metro
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 2 | biloela
# Processing Record 27 of Set 2 | saint-georges
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | flinders
# Processing Record 30 of Set 2 | torbay
# Processing Record 31 of Set 2 | nicoya
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | leshukonskoye
# Processing Record 37 of Set 2 | auki
# Processing Record 38 of Set 2 | kieta
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | okhotsk
# Processing Record 42 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | iqaluit
# Processing Record 45 of Set 2 | presidente epitacio
# Processing Record 46 of Set 2 | den helder
# Processing Record 47 of Set 2 | morazan
# Processing Record 48 of Set 2 | sangre grande
# Processing Record 49 of Set 2 | bontang
# Processing Record 50 of Set 2 | kalmunai
# Processing Record 1 of Set 3 | mataura
# Processing Record 2 of Set 3 | cap malheureux
# Processing Record 3 of Set 3 | cidreira
# Processing Record 4 of Set 3 | waw
# Processing Record 5 of Set 3 | peyima
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 3 | cayenne
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | srednekolymsk
# Processing Record 11 of Set 3 | hithadhoo
# Processing Record 12 of Set 3 | la ronge
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | san cristobal
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | carberry
# Processing Record 17 of Set 3 | gushi
# Processing Record 18 of Set 3 | parabel
# Processing Record 19 of Set 3 | tuatapere
# Processing Record 20 of Set 3 | belaya gora
# Processing Record 21 of Set 3 | khani
# Processing Record 22 of Set 3 | eureka
# Processing Record 23 of Set 3 | itoman
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | logan lake
# Processing Record 26 of Set 3 | lima
# Processing Record 27 of Set 3 | upernavik
# Processing Record 28 of Set 3 | abu kamal
# Processing Record 29 of Set 3 | bluff
# Processing Record 30 of Set 3 | hofn
# Processing Record 31 of Set 3 | beringovskiy
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | uray
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | mujiayingzi
# Processing Record 36 of Set 3 | jacksonville
# Processing Record 37 of Set 3 | shellbrook
# Processing Record 38 of Set 3 | merano
# Processing Record 39 of Set 3 | obluche
# City not found. Skipping...
# Processing Record 40 of Set 3 | brcko
# Processing Record 41 of Set 3 | kirkwall
# Processing Record 42 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 3 | wadi maliz
# Processing Record 44 of Set 3 | elizabeth city
# Processing Record 45 of Set 3 | nouakchott
# Processing Record 46 of Set 3 | adrar
# Processing Record 47 of Set 3 | trairi
# Processing Record 48 of Set 3 | saldanha
# Processing Record 49 of Set 3 | manbij
# Processing Record 50 of Set 3 | vardo
# Processing Record 1 of Set 4 | lata
# Processing Record 2 of Set 4 | lorengau
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | talakan
# Processing Record 5 of Set 4 | omsukchan
# Processing Record 6 of Set 4 | souillac
# Processing Record 7 of Set 4 | neuquen
# Processing Record 8 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 4 | hermanus
# Processing Record 10 of Set 4 | tyup
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | llata
# Processing Record 13 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 4 | nurota
# Processing Record 15 of Set 4 | severnoye
# Processing Record 16 of Set 4 | adelaide
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | moree
# Processing Record 19 of Set 4 | poum
# Processing Record 20 of Set 4 | belyy yar
# Processing Record 21 of Set 4 | xichang
# Processing Record 22 of Set 4 | dikson
# Processing Record 23 of Set 4 | ulaangom
# Processing Record 24 of Set 4 | jamestown
# Processing Record 25 of Set 4 | narsaq
# Processing Record 26 of Set 4 | hobyo
# Processing Record 27 of Set 4 | hilo
# Processing Record 28 of Set 4 | praia da vitoria
# Processing Record 29 of Set 4 | barcelona
# Processing Record 30 of Set 4 | cherskiy
# Processing Record 31 of Set 4 | vestmannaeyjar
# Processing Record 32 of Set 4 | guerrero negro
# Processing Record 33 of Set 4 | asfi
# Processing Record 34 of Set 4 | deputatskiy
# Processing Record 35 of Set 4 | popondetta
# Processing Record 36 of Set 4 | kavieng
# Processing Record 37 of Set 4 | te anau
# Processing Record 38 of Set 4 | yumen
# Processing Record 39 of Set 4 | northam
# Processing Record 40 of Set 4 | lodwar
# Processing Record 41 of Set 4 | peringat
# Processing Record 42 of Set 4 | kudahuvadhoo
# Processing Record 43 of Set 4 | hambantota
# Processing Record 44 of Set 4 | bengkulu
# Processing Record 45 of Set 4 | aquin
# Processing Record 46 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | provideniya
# Processing Record 49 of Set 4 | yar-sale
# Processing Record 50 of Set 4 | pringsewu
# Processing Record 1 of Set 5 | itupiranga
# Processing Record 2 of Set 5 | morehead
# Processing Record 3 of Set 5 | faanui
# Processing Record 4 of Set 5 | candolim
# Processing Record 5 of Set 5 | soe
# Processing Record 6 of Set 5 | curitibanos
# Processing Record 7 of Set 5 | vila velha
# Processing Record 8 of Set 5 | pombia
# Processing Record 9 of Set 5 | caucaia
# Processing Record 10 of Set 5 | nampula
# Processing Record 11 of Set 5 | touros
# Processing Record 12 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 5 | urucara
# Processing Record 14 of Set 5 | puerto penasco
# Processing Record 15 of Set 5 | manokwari
# Processing Record 16 of Set 5 | taseyevo
# Processing Record 17 of Set 5 | uyaan
# Processing Record 18 of Set 5 | babu
# Processing Record 19 of Set 5 | port blair
# Processing Record 20 of Set 5 | nelson bay
# Processing Record 21 of Set 5 | mar del plata
# Processing Record 22 of Set 5 | blairmore
# Processing Record 23 of Set 5 | seoul
# Processing Record 24 of Set 5 | ixtapa
# Processing Record 25 of Set 5 | arraial do cabo
# Processing Record 26 of Set 5 | kendari
# Processing Record 27 of Set 5 | moerai
# Processing Record 28 of Set 5 | tasiilaq
# Processing Record 29 of Set 5 | hami
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | dasoguz
# Processing Record 32 of Set 5 | pryazha
# Processing Record 33 of Set 5 | narrabri
# Processing Record 34 of Set 5 | samarai
# Processing Record 35 of Set 5 | thompson
# Processing Record 36 of Set 5 | kawalu
# Processing Record 37 of Set 5 | nuevo progreso
# Processing Record 38 of Set 5 | olinda
# Processing Record 39 of Set 5 | namibe
# Processing Record 40 of Set 5 | namatanai
# Processing Record 41 of Set 5 | culpeper
# Processing Record 42 of Set 5 | cabedelo
# Processing Record 43 of Set 5 | airai
# Processing Record 44 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 5 | estacion coahuila
# Processing Record 46 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 5 | georgetown
# Processing Record 49 of Set 5 | moindou
# Processing Record 50 of Set 5 | sujiatun
# Processing Record 1 of Set 6 | podporozhye
# Processing Record 2 of Set 6 | inhambane
# Processing Record 3 of Set 6 | salalah
# Processing Record 4 of Set 6 | chokurdakh
# Processing Record 5 of Set 6 | sorland
# Processing Record 6 of Set 6 | svodna
# Processing Record 7 of Set 6 | chumikan
# Processing Record 8 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 9 of Set 6 | pangnirtung
# Processing Record 10 of Set 6 | viedma
# Processing Record 11 of Set 6 | sur
# Processing Record 12 of Set 6 | dimitrovgrad
# Processing Record 13 of Set 6 | smiltene
# Processing Record 14 of Set 6 | husavik
# Processing Record 15 of Set 6 | waingapu
# Processing Record 16 of Set 6 | sargatskoye
# Processing Record 17 of Set 6 | san patricio
# Processing Record 18 of Set 6 | pinhal novo
# Processing Record 19 of Set 6 | henties bay
# Processing Record 20 of Set 6 | the valley
# Processing Record 21 of Set 6 | yinchuan
# Processing Record 22 of Set 6 | marrakesh
# Processing Record 23 of Set 6 | upington
# Processing Record 24 of Set 6 | bubaque
# Processing Record 25 of Set 6 | alexandria
# Processing Record 26 of Set 6 | buala
# Processing Record 27 of Set 6 | iquitos
# Processing Record 28 of Set 6 | griffith
# Processing Record 29 of Set 6 | carauari
# Processing Record 30 of Set 6 | rosetta
# Processing Record 31 of Set 6 | vaimela
# City not found. Skipping...
# Processing Record 32 of Set 6 | kodiak
# Processing Record 33 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 6 | balangir
# Processing Record 35 of Set 6 | kangaatsiaq
# Processing Record 36 of Set 6 | boyolangu
# Processing Record 37 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 6 | bilma
# Processing Record 40 of Set 6 | ballina
# Processing Record 41 of Set 6 | cap-aux-meules
# Processing Record 42 of Set 6 | ostrovnoy
# Processing Record 43 of Set 6 | lompoc
# Processing Record 44 of Set 6 | lazaro cardenas
# Processing Record 45 of Set 6 | los llanos de aridane
# Processing Record 46 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 6 | harnosand
# Processing Record 48 of Set 6 | sao jose da coroa grande
# Processing Record 49 of Set 6 | luderitz
# Processing Record 50 of Set 6 | meulaboh
# Processing Record 1 of Set 7 | morros
# Processing Record 2 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 3 of Set 7 | karia
# Processing Record 4 of Set 7 | banyo
# Processing Record 5 of Set 7 | pacific grove
# Processing Record 6 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 7 | puro
# Processing Record 8 of Set 7 | bathsheba
# Processing Record 9 of Set 7 | chimbote
# Processing Record 10 of Set 7 | pokrovsk
# Processing Record 11 of Set 7 | gorom-gorom
# Processing Record 12 of Set 7 | dergachi
# Processing Record 13 of Set 7 | laguna
# Processing Record 14 of Set 7 | tessalit
# Processing Record 15 of Set 7 | chernyshevskiy
# Processing Record 16 of Set 7 | ponta do sol
# Processing Record 17 of Set 7 | norman wells
# Processing Record 18 of Set 7 | macklin
# Processing Record 19 of Set 7 | rocha
# Processing Record 20 of Set 7 | qasigiannguit
# Processing Record 21 of Set 7 | lishu
# Processing Record 22 of Set 7 | turukhansk
# Processing Record 23 of Set 7 | novikovo
# Processing Record 24 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 7 | bethel
# Processing Record 27 of Set 7 | neiafu
# Processing Record 28 of Set 7 | havre-saint-pierre
# Processing Record 29 of Set 7 | kahului
# Processing Record 30 of Set 7 | pevek
# Processing Record 31 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 7 | altay
# Processing Record 33 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 7 | tari
# Processing Record 36 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 7 | gayeri
# Processing Record 38 of Set 7 | bandundu
# Processing Record 39 of Set 7 | monrovia
# Processing Record 40 of Set 7 | tomatlan
# Processing Record 41 of Set 7 | jardim
# Processing Record 42 of Set 7 | caruray
# Processing Record 43 of Set 7 | jonesboro
# Processing Record 44 of Set 7 | severodvinsk
# Processing Record 45 of Set 7 | filadelfia
# Processing Record 46 of Set 7 | kangaba
# Processing Record 47 of Set 7 | beloha
# Processing Record 48 of Set 7 | komsomolskiy
# Processing Record 49 of Set 7 | labuhan
# Processing Record 50 of Set 7 | crixas
# Processing Record 1 of Set 8 | oistins
# Processing Record 2 of Set 8 | alamosa
# Processing Record 3 of Set 8 | barrow
# Processing Record 4 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 5 of Set 8 | creel
# Processing Record 6 of Set 8 | anloga
# Processing Record 7 of Set 8 | vila franca do campo
# Processing Record 8 of Set 8 | fazilka
# Processing Record 9 of Set 8 | alofi
# Processing Record 10 of Set 8 | cockburn town
# Processing Record 11 of Set 8 | coquimbo
# Processing Record 12 of Set 8 | victoria
# Processing Record 13 of Set 8 | kruisfontein
# Processing Record 14 of Set 8 | lincoln
# Processing Record 15 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 16 of Set 8 | brignoles
# Processing Record 17 of Set 8 | dombarovskiy
# Processing Record 18 of Set 8 | saint george
# Processing Record 19 of Set 8 | hong gai
# Processing Record 20 of Set 8 | tirumullaivasal
# Processing Record 21 of Set 8 | sao filipe
# Processing Record 22 of Set 8 | mithimna
# City not found. Skipping...
# Processing Record 23 of Set 8 | addis zemen
# City not found. Skipping...
# Processing Record 24 of Set 8 | borogontsy
# Processing Record 25 of Set 8 | dolores
# Processing Record 26 of Set 8 | majene
# Processing Record 27 of Set 8 | kuching
# Processing Record 28 of Set 8 | lagoa
# Processing Record 29 of Set 8 | cassilandia
# Processing Record 30 of Set 8 | alta floresta
# Processing Record 31 of Set 8 | mihaesti
# Processing Record 32 of Set 8 | constitucion
# Processing Record 33 of Set 8 | bereda
# Processing Record 34 of Set 8 | pandan
# Processing Record 35 of Set 8 | chimore
# Processing Record 36 of Set 8 | japura
# Processing Record 37 of Set 8 | marawi
# Processing Record 38 of Set 8 | grand gaube
# Processing Record 39 of Set 8 | bam
# Processing Record 40 of Set 8 | punta de bombon
# Processing Record 41 of Set 8 | champerico
# Processing Record 42 of Set 8 | mandali
# Processing Record 43 of Set 8 | muzhi
# Processing Record 44 of Set 8 | jiaojiang
# Processing Record 45 of Set 8 | valderrama
# Processing Record 46 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 8 | goryachiy klyuch
# Processing Record 48 of Set 8 | gizo
# Processing Record 49 of Set 8 | oranjemund
# Processing Record 50 of Set 8 | baghdad
# Processing Record 1 of Set 9 | chaupimarca
# Processing Record 2 of Set 9 | waipawa
# Processing Record 3 of Set 9 | moville
# Processing Record 4 of Set 9 | moron
# Processing Record 5 of Set 9 | susangerd
# Processing Record 6 of Set 9 | wamba
# Processing Record 7 of Set 9 | ondjiva
# Processing Record 8 of Set 9 | grindavik
# Processing Record 9 of Set 9 | ahuimanu
# Processing Record 10 of Set 9 | dagana
# Processing Record 11 of Set 9 | awbari
# Processing Record 12 of Set 9 | dipkarpaz
# City not found. Skipping...
# Processing Record 13 of Set 9 | mkushi
# Processing Record 14 of Set 9 | sironko
# Processing Record 15 of Set 9 | sao joao da barra
# Processing Record 16 of Set 9 | zhenjiang
# Processing Record 17 of Set 9 | kytlym
# City not found. Skipping...
# Processing Record 18 of Set 9 | mount gambier
# Processing Record 19 of Set 9 | zheleznodorozhnyy
# Processing Record 20 of Set 9 | rawson
# Processing Record 21 of Set 9 | holme
# Processing Record 22 of Set 9 | biak
# Processing Record 23 of Set 9 | fort nelson
# Processing Record 24 of Set 9 | zholymbet
# Processing Record 25 of Set 9 | luanda
# Processing Record 26 of Set 9 | assiniboia
# Processing Record 27 of Set 9 | mayo
# Processing Record 28 of Set 9 | lira
# Processing Record 29 of Set 9 | ilulissat
# Processing Record 30 of Set 9 | albury
# Processing Record 31 of Set 9 | vilhena
# Processing Record 32 of Set 9 | abu zabad
# Processing Record 33 of Set 9 | port macquarie
# Processing Record 34 of Set 9 | marsh harbour
# Processing Record 35 of Set 9 | artyom
# Processing Record 36 of Set 9 | port hedland
# Processing Record 37 of Set 9 | codrington
# Processing Record 38 of Set 9 | la seyne-sur-mer
# Processing Record 39 of Set 9 | nikolayevka
# Processing Record 40 of Set 9 | naliya
# Processing Record 41 of Set 9 | nara
# Processing Record 42 of Set 9 | trapani
# Processing Record 43 of Set 9 | saint-augustin
# Processing Record 44 of Set 9 | barra da estiva
# Processing Record 45 of Set 9 | hovd
# Processing Record 46 of Set 9 | grinnell
# Processing Record 47 of Set 9 | pontianak
# Processing Record 48 of Set 9 | surt
# Processing Record 49 of Set 9 | tecoanapa
# Processing Record 50 of Set 9 | mitsamiouli
# Processing Record 1 of Set 10 | makakilo city
# Processing Record 2 of Set 10 | pisco
# Processing Record 3 of Set 10 | tual
# Processing Record 4 of Set 10 | high prairie
# Processing Record 5 of Set 10 | taoudenni
# Processing Record 6 of Set 10 | indramayu
# Processing Record 7 of Set 10 | sinnamary
# Processing Record 8 of Set 10 | ningan
# City not found. Skipping...
# Processing Record 9 of Set 10 | rovnoye
# Processing Record 10 of Set 10 | tazovskiy
# Processing Record 11 of Set 10 | half moon bay
# Processing Record 12 of Set 10 | mapiri
# Processing Record 13 of Set 10 | saravan
# Processing Record 14 of Set 10 | bismarck
# Processing Record 15 of Set 10 | sola
# Processing Record 16 of Set 10 | thinadhoo
# Processing Record 17 of Set 10 | bijar
# Processing Record 18 of Set 10 | tahoua
# Processing Record 19 of Set 10 | krasnyy chikoy
# Processing Record 20 of Set 10 | marratxi
# Processing Record 21 of Set 10 | kailua
# Processing Record 22 of Set 10 | severo-kurilsk
# Processing Record 23 of Set 10 | coahuayana
# Processing Record 24 of Set 10 | kushmurun
# Processing Record 25 of Set 10 | thio
# Processing Record 26 of Set 10 | margate
# Processing Record 27 of Set 10 | chuy
# Processing Record 28 of Set 10 | egvekinot
# Processing Record 29 of Set 10 | dukat
# Processing Record 30 of Set 10 | alyangula
# Processing Record 31 of Set 10 | obra
# Processing Record 32 of Set 10 | iskateley
# Processing Record 33 of Set 10 | havelock
# Processing Record 34 of Set 10 | banjarmasin
# Processing Record 35 of Set 10 | ayr
# Processing Record 36 of Set 10 | byron bay
# Processing Record 37 of Set 10 | lebu
# Processing Record 38 of Set 10 | geraldton
# Processing Record 39 of Set 10 | hearst
# Processing Record 40 of Set 10 | hillsborough
# Processing Record 41 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 10 | kidal
# Processing Record 43 of Set 10 | santa cruz
# Processing Record 44 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 10 | aichach
# Processing Record 46 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 47 of Set 10 | magdagachi
# Processing Record 48 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 10 | krasnoselkup
# Processing Record 50 of Set 10 | vao
# Processing Record 1 of Set 11 | okato
# Processing Record 2 of Set 11 | kamaishi
# Processing Record 3 of Set 11 | chengmai
# City not found. Skipping...
# Processing Record 4 of Set 11 | wonthaggi
# Processing Record 5 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 11 | fairbanks
# Processing Record 7 of Set 11 | kristiansund
# Processing Record 8 of Set 11 | pangai
# Processing Record 9 of Set 11 | rio grande
# Processing Record 10 of Set 11 | naze
# Processing Record 11 of Set 11 | usinsk
# Processing Record 12 of Set 11 | ponta delgada
# Processing Record 13 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 11 | mikhaylovka
# Processing Record 15 of Set 11 | peterhead
# Processing Record 16 of Set 11 | andenes
# Processing Record 17 of Set 11 | suntar
# Processing Record 18 of Set 11 | tokmak
# Processing Record 19 of Set 11 | broome
# Processing Record 20 of Set 11 | harlingen
# Processing Record 21 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 11 | mubende
# Processing Record 23 of Set 11 | sawtell
# Processing Record 24 of Set 11 | langxiang
# Processing Record 25 of Set 11 | nelson
# Processing Record 26 of Set 11 | rochegda
# Processing Record 27 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 11 | erenhot
# Processing Record 29 of Set 11 | pitkyaranta
# Processing Record 30 of Set 11 | atherton
# Processing Record 31 of Set 11 | gat
# Processing Record 32 of Set 11 | sierra vista
# Processing Record 33 of Set 11 | lakes entrance
# Processing Record 34 of Set 11 | bandarbeyla
# Processing Record 35 of Set 11 | celestun
# Processing Record 36 of Set 11 | turan
# Processing Record 37 of Set 11 | beidao
# Processing Record 38 of Set 11 | mattoon
# Processing Record 39 of Set 11 | darhan
# Processing Record 40 of Set 11 | atasu
# Processing Record 41 of Set 11 | shu
# Processing Record 42 of Set 11 | dire
# Processing Record 43 of Set 11 | wadi musa
# Processing Record 44 of Set 11 | lengshuitan
# Processing Record 45 of Set 11 | lagos
# Processing Record 46 of Set 11 | foki
# Processing Record 47 of Set 11 | sri aman
# Processing Record 48 of Set 11 | flin flon
# Processing Record 49 of Set 11 | kizhinga
# Processing Record 50 of Set 11 | san ramon
# Processing Record 1 of Set 12 | nizhniy tsasuchey
# Processing Record 2 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 12 | sept-iles
# Processing Record 4 of Set 12 | akdepe
# Processing Record 5 of Set 12 | todos santos
# Processing Record 6 of Set 12 | tiarei
# Processing Record 7 of Set 12 | maceio
# Processing Record 8 of Set 12 | pascagoula
# Processing Record 9 of Set 12 | nova mayachka
# Processing Record 10 of Set 12 | binga
# Processing Record 11 of Set 12 | xiongzhou
# Processing Record 12 of Set 12 | murgab
# Processing Record 13 of Set 12 | ocampo
# Processing Record 14 of Set 12 | asau
# Processing Record 15 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 16 of Set 12 | cabra
# Processing Record 17 of Set 12 | carutapera
# Processing Record 18 of Set 12 | pincher creek
# Processing Record 19 of Set 12 | kyrksaeterora
# Processing Record 20 of Set 12 | kisangani
# Processing Record 21 of Set 12 | mana
# Processing Record 22 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 12 | valle de allende
# Processing Record 24 of Set 12 | batagay
# Processing Record 25 of Set 12 | kosonsoy
# Processing Record 26 of Set 12 | tahe
# Processing Record 27 of Set 12 | davila
# Processing Record 28 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 29 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 12 | coacoyul
# Processing Record 31 of Set 12 | tiznit
# Processing Record 32 of Set 12 | janakkala
# Processing Record 33 of Set 12 | buenos aires
# Processing Record 34 of Set 12 | caborca
# Processing Record 35 of Set 12 | conceicao do araguaia
# Processing Record 36 of Set 12 | williams lake
# Processing Record 37 of Set 12 | maralal
# Processing Record 38 of Set 12 | sinaloa
# Processing Record 39 of Set 12 | amatlan
# City not found. Skipping...
# Processing Record 40 of Set 12 | barsbuttel
# City not found. Skipping...
# Processing Record 41 of Set 12 | opuwo
# Processing Record 42 of Set 12 | monywa
# Processing Record 43 of Set 12 | rorvik
# Processing Record 44 of Set 12 | auka
# Processing Record 45 of Set 12 | villa bisono
# Processing Record 46 of Set 12 | dingle
# Processing Record 47 of Set 12 | qazvin
# Processing Record 48 of Set 12 | puerto madryn
# Processing Record 49 of Set 12 | luyang
# Processing Record 50 of Set 12 | wagar
# Processing Record 1 of Set 13 | toktogul
# Processing Record 2 of Set 13 | ambanja
# Processing Record 3 of Set 13 | tabas
# Processing Record 4 of Set 13 | nyurba
# Processing Record 5 of Set 13 | ketchikan
# Processing Record 6 of Set 13 | teahupoo
# Processing Record 7 of Set 13 | okha
# Processing Record 8 of Set 13 | koshurnikovo
# Processing Record 9 of Set 13 | tura
# Processing Record 10 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 13 | padang
# Processing Record 12 of Set 13 | zverinogolovskoye
# Processing Record 13 of Set 13 | ust-kuyga
# Processing Record 14 of Set 13 | shaunavon
# Processing Record 15 of Set 13 | lubango
# Processing Record 16 of Set 13 | vanimo
# Processing Record 17 of Set 13 | taloqan
# Processing Record 18 of Set 13 | mathathane
# Processing Record 19 of Set 13 | maun
# Processing Record 20 of Set 13 | soskovo
# Processing Record 21 of Set 13 | yerbogachen
# Processing Record 22 of Set 13 | severo-yeniseyskiy
# Processing Record 23 of Set 13 | yulara
# Processing Record 24 of Set 13 | acarau
# Processing Record 25 of Set 13 | hualmay
# Processing Record 26 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 27 of Set 13 | carballo
# Processing Record 28 of Set 13 | karaton
# Processing Record 29 of Set 13 | sandy bay
# Processing Record 30 of Set 13 | asht
# City not found. Skipping...
# Processing Record 31 of Set 13 | soyo
# Processing Record 32 of Set 13 | yurgamysh
# Processing Record 33 of Set 13 | emerald
# Processing Record 34 of Set 13 | aranos
# Processing Record 35 of Set 13 | jalu
# Processing Record 36 of Set 13 | nabire
# Processing Record 37 of Set 13 | palmela
# Processing Record 38 of Set 13 | san andres
# Processing Record 39 of Set 13 | glodeni
# Processing Record 40 of Set 13 | camacha
# Processing Record 41 of Set 13 | finschhafen
# Processing Record 42 of Set 13 | piacabucu
# Processing Record 43 of Set 13 | mbarara
# Processing Record 44 of Set 13 | aracati
# Processing Record 45 of Set 13 | ust-kishert
# Processing Record 46 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 13 | burica
# City not found. Skipping...
# Processing Record 48 of Set 13 | san cosme y damian
# Processing Record 49 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 13 | lakatoro
# Processing Record 1 of Set 14 | san pedro de ycuamandiyu
# Processing Record 2 of Set 14 | port lincoln
# Processing Record 3 of Set 14 | tieling
# Processing Record 4 of Set 14 | claudio
# Processing Record 5 of Set 14 | gerash
# Processing Record 6 of Set 14 | lanzhou
# Processing Record 7 of Set 14 | payo
# Processing Record 8 of Set 14 | francistown
# Processing Record 9 of Set 14 | chulman
# Processing Record 10 of Set 14 | sioux lookout
# Processing Record 11 of Set 14 | tezu
# Processing Record 12 of Set 14 | lavrentiya
# Processing Record 13 of Set 14 | atambua
# Processing Record 14 of Set 14 | realeza
# Processing Record 15 of Set 14 | port hardy
# Processing Record 16 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 14 | sao francisco do conde
# Processing Record 19 of Set 14 | bumba
# Processing Record 20 of Set 14 | prince rupert
# Processing Record 21 of Set 14 | obihiro
# Processing Record 22 of Set 14 | heihe
# Processing Record 23 of Set 14 | sabzevar
# Processing Record 24 of Set 14 | xining
# Processing Record 25 of Set 14 | pombas
# Processing Record 26 of Set 14 | tsentralnyy
# City not found. Skipping...
# Processing Record 27 of Set 14 | caravelas
# Processing Record 28 of Set 14 | rivera
# Processing Record 29 of Set 14 | bairiki
# Processing Record 30 of Set 14 | americus
# Processing Record 31 of Set 14 | rockhampton
# Processing Record 32 of Set 14 | porto walter
# Processing Record 33 of Set 14 | chitral
# Processing Record 34 of Set 14 | iralaya
# Processing Record 35 of Set 14 | ipojuca
# Processing Record 36 of Set 14 | murmashi
# Processing Record 37 of Set 14 | broken hill
# Processing Record 38 of Set 14 | edea
# Processing Record 39 of Set 14 | elko
# Processing Record 40 of Set 14 | portland
# Processing Record 41 of Set 14 | kampot
# Processing Record 42 of Set 14 | uaua
# Processing Record 43 of Set 14 | maungaturoto
# Processing Record 44 of Set 14 | saint-francois
# Processing Record 45 of Set 14 | conakry
# Processing Record 46 of Set 14 | takapau
# Processing Record 47 of Set 14 | rio gallegos
# Processing Record 48 of Set 14 | roald
# Processing Record 49 of Set 14 | ravar
# Processing Record 50 of Set 14 | morrope
# Processing Record 1 of Set 15 | sabha
# Processing Record 2 of Set 15 | ranong
# Processing Record 3 of Set 15 | manta
# Processing Record 4 of Set 15 | makokou
# Processing Record 5 of Set 15 | acapulco
# Processing Record 6 of Set 15 | aksu
# Processing Record 7 of Set 15 | namwala
# Processing Record 8 of Set 15 | nizhniy kuranakh
# Processing Record 9 of Set 15 | tulca
# Processing Record 10 of Set 15 | ulaanbaatar
# Processing Record 11 of Set 15 | vazante
# Processing Record 12 of Set 15 | chaplynka
# Processing Record 13 of Set 15 | arlit
# Processing Record 14 of Set 15 | alice springs
# Processing Record 15 of Set 15 | luga
# Processing Record 16 of Set 15 | fare
# Processing Record 17 of Set 15 | mount isa
# Processing Record 18 of Set 15 | palasa
# Processing Record 19 of Set 15 | porto novo
# Processing Record 20 of Set 15 | camocim
# Processing Record 21 of Set 15 | hisai
# Processing Record 22 of Set 15 | palmer
# Processing Record 23 of Set 15 | zhanakorgan
# Processing Record 24 of Set 15 | ust-uda
# Processing Record 25 of Set 15 | tilichiki
# Processing Record 26 of Set 15 | linxia
# Processing Record 27 of Set 15 | xilagani
# Processing Record 28 of Set 15 | dharchula
# Processing Record 29 of Set 15 | bogdanovich
# Processing Record 30 of Set 15 | rujewa
# Processing Record 31 of Set 15 | escanaba
# Processing Record 32 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 15 | barmer
# Processing Record 34 of Set 15 | chinhoyi
# Processing Record 35 of Set 15 | plettenberg bay
# Processing Record 36 of Set 15 | brewer
# Processing Record 37 of Set 15 | issa
# Processing Record 38 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 15 | port hawkesbury
# Processing Record 40 of Set 15 | el real de santa maria
# Processing Record 41 of Set 15 | gambela
# Processing Record 42 of Set 15 | manica
# Processing Record 43 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 44 of Set 15 | pattani
# Processing Record 45 of Set 15 | odweyne
# Processing Record 46 of Set 15 | gouyave
# Processing Record 47 of Set 15 | bend
# Processing Record 48 of Set 15 | stettler
# Processing Record 49 of Set 15 | colon
# Processing Record 50 of Set 15 | faya
# Processing Record 1 of Set 16 | camapua
# Processing Record 2 of Set 16 | labytnangi
# Processing Record 3 of Set 16 | oktyabrskoye
# Processing Record 4 of Set 16 | koslan
# Processing Record 5 of Set 16 | tynda
# Processing Record 6 of Set 16 | douglas
# Processing Record 7 of Set 16 | rameswaram
# Processing Record 8 of Set 16 | barrancabermeja
# Processing Record 9 of Set 16 | tubruq
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Albany      US  42.6001  -73.9662     28.74        55          19
# 1        Dutse      NG  11.7594    9.3392     63.91        21           0
# 2      Rikitea      PF -23.1203 -134.9692     78.48        74         100
# 3  San Quintin      MX  30.4833 -115.9500     65.39        56           0
# 4   Nouadhibou      MR  20.9310  -17.0347     69.78        68         100
# 5    Salaverry      PE  -8.2333  -78.9667     70.18        83          78
# 6    Lebyazhye      RU  55.2689   66.4947      6.13        91         100
# 7       Avarua      CK -21.2078 -159.7750     80.65        89          75
# 8      Ahipara      NZ -35.1667  173.1667     64.53        63          56
# 9    Cape Town      ZA -33.9258   18.4232     68.41        68           0
#
#    Wind Speed Current Description
# 0        5.01          few clouds
# 1        9.66           clear sky
# 2        9.06     overcast clouds
# 3        4.65           clear sky
# 4       11.50     overcast clouds
# 5       13.27       broken clouds
# 6        7.61     overcast clouds
# 7        9.22       broken clouds
# 8        8.08       broken clouds
# 9        4.00           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
